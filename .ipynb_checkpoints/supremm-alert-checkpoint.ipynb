# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import date
import datetime
import requests
import json

import xdmod.datawarehouse as xdw
import xdmod.visualizer as v
import xdmod.visualizer_test as vt

from IPython.display import display, Markdown, JSON

# %%
# config variables

# dictionary mapping hostname -> url
hosts = {'metrics-dev': 'https://metrics-dev.ccr.buffalo.edu:9004', 
         'ookami': 'https://ookami.ccr.xdmod.org',
         'xdmod-dev': 'https://xdmod-dev.ccr.xdmod.org:9002'}

# today -> monday when notebook is executed
today = date.today()
sunday = today - datetime.timedelta(days=1)
last_monday = today - datetime.timedelta(days=7)
last_sunday = last_monday - datetime.timedelta(days=1)
lastlast_monday = last_monday - datetime.timedelta(days=7)

# %% [markdown]
# # Full Report

# %%
for host in hosts:
    display(Markdown(f'## {host}'))
    for type in ['gpu','hardware', 'cpu','realms', 'script']:
        config = {"start": last_monday, "end": sunday, "type": type}
        config_lastweek = {"start": lastlast_monday, "end": last_sunday, "type": type}  
        with xdw.DataWareHouse(hosts[host]) as test:
                data = test.get_qualitydata(config)
                lastweek_data = test.get_qualitydata(config_lastweek)
                vt.quality_heatmap(data,lastweek_data)
# Out:
# # metrics-dev
# # ookami
# # xdmod-dev
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /var/folders/qc/6bk8jy_55f731bhgzvw3sd880000gn/T/ipykernel_53568/144580374.py in <module>
#       5         config_lastweek = {"start": lastlast_monday, "end": last_sunday, "type": type}
#       6         with xdw.DataWareHouse(hosts[host]) as test:
# ----> 7                 data = test.get_qualitydata(config)
#       8                 lastweek_data = test.get_qualitydata(config_lastweek)
#       9                 vt.quality_heatmap(data,lastweek_data)
#
# ~/Desktop/CCR/xdmod-alerts/xdmod/datawarehouse.py in get_qualitydata(self, params, is_numpy)
#     336             return df
#     337         else:
# --> 338             raise RuntimeError('Error ' + str(code) + ' ' + get_body.decode('utf8'))
#     339
#     340     '''
#
# RuntimeError: Error 500 {"success":false,"count":0,"total":0,"totalCount":0,"results":[],"data":[],"message":"SQLSTATE[42S22]: Column not found: 1054 Unknown column 'sf.gpu0_nv_utilization_bucketid' in 'field list'","code":"42S22"}

# %%
# alerts setup

# path to report in html format
html_path = f'reports/xdmod-alerts/{today.strftime("%Y-%m-%d")}_report.html'

# Slack webhook for post request
# DO NOT EXPOSE ON GITHUB
webhook = ''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/qc/6bk8jy_55f731bhgzvw3sd880000gn/T/ipykernel_77514/2411971945.py in <module>
#       2
#       3 # path to report in html format
# ----> 4 html_path = f'reports/xdmod-alerts/{today.strftime("%Y-%m-%d")}_report.html'
#       5
#       6 # Slack webhook for post request
#
# NameError: name 'today' is not defined

# %%
type_to_title = {'gpu': '% of CCR SUPReMM jobs with GPU information', 
                'hardware': '% of CCR SUPReMM jobs with hardware perf information', 
                'cpu': '% of CCR SUPReMM jobs with cpu usage information', 
                'script': '% of CCR SUPReMM jobs with Job Batch Script information', 
                'realms': '% of CCR jobs in the SUPReMM realm compared to Jobs realm'}

payload = {"blocks": [{"type": "section","text": {"type": "mrkdwn","text": f'*SUPReMM Quality Alerts {today}*'}}]}

for host in hosts:
    with xdw.DataWareHouse(host) as warehouse:
        for type in ['gpu', 'hardware', 'cpu', 'realms']:
            today_data = warehouse.get_qualitydata({"start": last_monday, "end": sunday, "type": type})
            lastweek_data = warehouse.get_qualitydata({"start": lastlast_monday, "end": last_sunday, "type": type})
            for res in today_data.index:
                if lastweek_data.mean(axis='columns')[res] + today_data.mean(axis='columns')[res] >= 10: # change to minus
                    alert = today_data.loc[res]
                    payload['blocks'].append({"type": "section","text": {"type": "mrkdwn","text": f'Attention needed at: *{type_to_title[type]}* from the *{alert.name}* resource'}})

    payload['blocks'].append({"type": "section","text": {"type": "mrkdwn","text": f'{host}/{html_path}'}})                
                
    response = requests.post(webhook, data = json.dumps(payload))
    print(response.text)
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# /var/folders/qc/6bk8jy_55f731bhgzvw3sd880000gn/T/ipykernel_74773/699683393.py in <module>
#      19     payload['blocks'].append({"type": "section","text": {"type": "mrkdwn","text": f'{host}/{html_path}'}})
#      20
# ---> 21     response = requests.post(webhook, data = json.dumps(payload))
#      22     print(response.text)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     115     """
#     116
# --> 117     return request('post', url, data=data, json=json, **kwargs)
#     118
#     119
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     526             hooks=hooks,
#     527         )
# --> 528         prep = self.prepare_request(req)
#     529
#     530         proxies = proxies or {}
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in prepare_request(self, request)
#     454
#     455         p = PreparedRequest()
# --> 456         p.prepare(
#     457             method=request.method.upper(),
#     458             url=request.url,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     314
#     315         self.prepare_method(method)
# --> 316         self.prepare_url(url, params)
#     317         self.prepare_headers(headers)
#     318         self.prepare_cookies(cookies)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/models.py in prepare_url(self, url, params)
#     388             error = error.format(to_native_string(url, 'utf8'))
#     389
# --> 390             raise MissingSchema(error)
#     391
#     392         if not host:
#
# MissingSchema: Invalid URL '': No schema supplied. Perhaps you meant http://?
